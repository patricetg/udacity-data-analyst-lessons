# %% [markdown]
# Let's use descriptive statistics and visualizations to address the question we posed with the cancer data earlier in the lesson. Does the size of a tumor affect its malignancy?

# %% [markdown]
# *Refer to my personal notes (in word file), part III (Data Analysis Process) - 2 (Data Analysis Process Overview) - d (Draw conclusion) - ii (exercice) in order to exploit this notebook.*

# %%
import pandas as pd
import matplotlib.pyplot as plt

% matplotlib inline

# %%
df = pd.read_csv("cancer_data.csv")
df.head().T
# Out:
#                                0         1         2         3         4
# id                        842302    842517  84300903  84348301  84358402
# diagnosis                      M         M         M         M         M
# radius_mean                17.99     20.57     19.69     11.42     20.29
# texture_mean                 NaN     17.77     21.25     20.38     14.34
# perimeter_mean             122.8     132.9       130     77.58     135.1
# area_mean                   1001      1326      1203     386.1      1297
# smoothness_mean           0.1184   0.08474    0.1096       NaN    0.1003
# compactness_mean          0.2776   0.07864    0.1599    0.2839    0.1328
# concavity_mean            0.3001    0.0869    0.1974    0.2414     0.198
# concave_points_mean       0.1471   0.07017    0.1279    0.1052    0.1043
# symmetry_mean             0.2419    0.1812    0.2069    0.2597    0.1809
# fractal_dimension_mean   0.07871   0.05667   0.05999   0.09744   0.05883
# ...

# %%
df_m = df[ df["diagnosis"] == "M" ]
df_m.head().T
# Out:
#                                0         1         2         3         4
# id                        842302    842517  84300903  84348301  84358402
# diagnosis                      M         M         M         M         M
# radius_mean                17.99     20.57     19.69     11.42     20.29
# texture_mean                 NaN     17.77     21.25     20.38     14.34
# perimeter_mean             122.8     132.9       130     77.58     135.1
# area_mean                   1001      1326      1203     386.1      1297
# smoothness_mean           0.1184   0.08474    0.1096       NaN    0.1003
# compactness_mean          0.2776   0.07864    0.1599    0.2839    0.1328
# concavity_mean            0.3001    0.0869    0.1974    0.2414     0.198
# concave_points_mean       0.1471   0.07017    0.1279    0.1052    0.1043
# symmetry_mean             0.2419    0.1812    0.2069    0.2597    0.1809
# fractal_dimension_mean   0.07871   0.05667   0.05999   0.09744   0.05883
# ...

# %%
mask = df["diagnosis"]=="M"
mask
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19     False
# 20     False
# 21     False
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 539    False
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# 545    False
# 546    False
# 547    False
# 548    False
# 549    False
# 550    False
# 551    False
# 552    False
# 553    False
# 554    False
# 555    False
# 556    False
# 557    False
# 558    False
# 559    False
# 560    False
# 561    False
# 562     True
# 563     True
# 564     True
# 565     True
# 566     True
# 567     True
# 568    False
# Name: diagnosis, Length: 569, dtype: bool

# %%
df_m["area_mean"].describe()
# Out:
# count     211.000000
# mean      976.241706
# std       364.656699
# min       361.600000
# 25%       708.100000
# 50%       930.900000
# 75%      1198.500000
# max      2501.000000
# Name: area_mean, dtype: float64

# %%
mask = df["diagnosis"]=="B"
df_b = df[ mask ]
df_b.head().T
# Out:
#                               19        20        21        37        40
# id                       8510426   8510653   8510824    854941  89511502
# diagnosis                      B         B         B         B         B
# radius_mean                13.54     13.08     9.504     13.03     12.67
# texture_mean               14.36     15.71     12.44     18.42      17.3
# perimeter_mean             87.46     85.63     60.34     82.61     81.25
# area_mean                  566.3       520     273.9     523.8     489.9
# smoothness_mean          0.09779    0.1075    0.1024   0.08983    0.1028
# compactness_mean         0.08129     0.127   0.06492   0.03766   0.07664
# concavity_mean           0.06664   0.04568   0.02956   0.02562   0.03193
# concave_points_mean      0.04781    0.0311   0.02076   0.02923   0.02107
# symmetry_mean             0.1885    0.1967    0.1815    0.1467    0.1707
# fractal_dimension_mean   0.05766   0.06811   0.06905   0.05863   0.05984
# ...

# %%
df_b["area_mean"].describe()
# Out:
# count    358.000000
# mean     462.944693
# std      134.621250
# min      143.500000
# 25%      374.975000
# 50%      458.550000
# 75%      551.550000
# max      992.100000
# Name: area_mean, dtype: float64

# %%
fig, ax = plt.subplots(figsize =(8,6))

ax.hist(df_b['area_mean'], alpha=0.5, label='benign')
ax.hist(df_m['area_mean'], alpha=0.5, label='malignant')

ax.set_title('Distributions of Benign and Malignant Tumor Areas')
ax.set_xlabel('Area')
ax.set_ylabel('Count')

ax.legend(loc='upper right')

plt.show();
