# %% [markdown]
# ## Common Programmatic Assessments in pandas
# ### Gather

# %%
import pandas as pd

# %%
patients = pd.read_csv('patients.csv')
treatments = pd.read_csv('treatments.csv')
adverse_reactions = pd.read_csv('adverse_reactions.csv')

# %% [markdown]
# ### Assess
# These are the programmatic assessment methods in pandas that you will probably use most often:
#
# * .head (DataFrame and Series)
# * .tail (DataFrame and Series)
# * .sample (DataFrame and Series)
# * .info (DataFrame only)
# * .describe (DataFrame and Series)
# * .value_counts (Series only)
# * Various methods of indexing and selecting data (.loc and bracket notation with/without boolean indexing, also .iloc)
#
# Try them out below and keep their results in mind. Some will come in handy later in the lesson.
#
# Check out the [pandas API reference](https://pandas.pydata.org/pandas-docs/stable/reference/index.html) for detailed usage information.

# %% [markdown]
# Try `.head` and `.tail` on the `patients` table.

# %%
patients.head().T
# Out:
#                                                  0  \
# patient_id                                       1
# assigned_sex                                female
# given_name                                     Zoe
# surname                                    Wellish
# address                       576 Brown Bear Drive
# city                             Rancho California
# state                                   California
# zip_code                                     92390
# country                              United States
# contact       951-719-9170ZoeWellish@superrito.com
# birthdate                                7/10/1976
# weight                                       121.7
# height                                          66
# bmi                                           19.6
#
#                                                   1  \
# patient_id                                        2
# assigned_sex                                 female
# given_name                                   Pamela
# surname                                        Hill
# address                   2370 University Hill Road
# city                                      Armstrong
# state                                      Illinois
# zip_code                                      61812
# country                               United States
# contact       PamelaSHill@cuvox.de+1 (217) 569-3204
# birthdate                                  4/3/1967
# weight                                        118.8
# height                                           66
# bmi                                            19.2
#
#                                              2  \
# patient_id                                   3
# assigned_sex                              male
# given_name                                 Jae
# surname                                 Debord
# address                  1493 Poling Farm Road
# city                                      York
# state                                 Nebraska
# zip_code                                 68467
# country                          United States
# contact       402-363-6804JaeMDebord@gustr.com
# birthdate                            2/19/1980
# weight                                   177.8
# height                                      71
# bmi                                       24.8
#
#                                                        3  \
# patient_id                                             4
# assigned_sex                                        male
# given_name                                          Liêm
# surname                                             Phan
# address                              2335 Webster Street
# city                                          Woodbridge
# state                                                 NJ
# zip_code                                            7095
# country                                    United States
# contact       PhanBaLiem@jourrapide.com+1 (732) 636-8246
# birthdate                                      7/26/1951
# weight                                             220.9
# height                                                70
# bmi                                                 31.7
#
#                                             4
# patient_id                                  5
# assigned_sex                             male
# given_name                                Tim
# surname                               Neudorf
# address                  1428 Turkey Pen Lane
# city                                   Dothan
# state                                      AL
# zip_code                                36303
# country                         United States
# contact       334-515-7487TimNeudorf@cuvox.de
# birthdate                           2/18/1928
# weight                                  192.3
# height                                     27
# bmi                                      26.1

# %%
patients.tail().T
# Out:
#                                                       498  \
# patient_id                                            499
# assigned_sex                                         male
# given_name                                        Mustafa
# surname                                         Lindström
# address                               2530 Victoria Court
# city                                         Milton Mills
# state                                                  ME
# zip_code                                             3852
# country                                     United States
# contact       207-477-0579MustafaLindstrom@jourrapide.com
# birthdate                                       4/10/1959
# weight                                              181.1
# height                                                 72
# bmi                                                  24.6
#
#                                              499  \
# patient_id                                   500
# assigned_sex                                male
# given_name                                 Ruman
# surname                                  Bisliev
# address                 494 Clarksburg Park Road
# city                                      Sedona
# state                                         AZ
# zip_code                                   86341
# country                            United States
# contact       928-284-4492RumanBisliev@gustr.com
# birthdate                              3/26/1948
# weight                                     239.6
# height                                        70
# bmi                                         34.4
#
#                                                 500  \
# patient_id                                      501
# assigned_sex                                 female
# given_name                                    Jinke
# surname                                   de Keizer
# address                           649 Nutter Street
# city                                  Overland Park
# state                                            MO
# zip_code                                      64110
# country                               United States
# contact       816-223-6007JinkedeKeizer@teleworm.us
# birthdate                                 1/13/1971
# weight                                        171.2
# height                                           67
# bmi                                            26.8
#
#                                                           501  \
# patient_id                                                502
# assigned_sex                                           female
# given_name                                            Chidalu
# surname                                           Onyekaozulu
# address                              3652 Boone Crockett Lane
# city                                                  Seattle
# state                                                      WA
# zip_code                                                98109
# country                                         United States
# contact       ChidaluOnyekaozulu@jourrapide.com1 360 443 2060
# birthdate                                           2/13/1952
# weight                                                  176.9
# height                                                     67
# bmi                                                      27.7
#
#                                                502
# patient_id                                     503
# assigned_sex                                  male
# given_name                                     Pat
# surname                                    Gersten
# address                          2778 North Avenue
# city                                          Burr
# state                                     Nebraska
# zip_code                                     68324
# country                              United States
# contact       PatrickGersten@rhyta.com402-848-4923
# birthdate                                 5/3/1954
# weight                                       138.2
# height                                          71
# bmi                                           19.3

# %% [markdown]
# Try `.sample` on the `treatments` table.

# %%
treatments.sample()
# Out:
#     given_name   surname auralin    novodra  hba1c_start  hba1c_end  \
# 105     finlay  sheppard       -  31u - 30u         7.51       7.17
#
#      hba1c_change
# 105          0.34

# %%
treatments.sample(3)
# Out:
#     given_name        surname    auralin novodra  hba1c_start  hba1c_end  \
# 7        eddie         archer  31u - 38u       -         7.89       7.55
# 145      ruman        bisliev  46u - 53u       -         7.72       7.39
# 193   svanhvít  guðjónsdóttir  37u - 44u       -         7.57       7.11
#
#      hba1c_change
# 7            0.34
# 145          0.33
# 193           NaN

# %% [markdown]
# Try `.info` on the `treatments` table.

# %%
treatments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
# given_name      280 non-null object
# surname         280 non-null object
# auralin         280 non-null object
# novodra         280 non-null object
# hba1c_start     280 non-null float64
# hba1c_end       280 non-null float64
# hba1c_change    171 non-null float64
# dtypes: float64(3), object(4)
# memory usage: 15.4+ KB

# %% [markdown]
# Try `.describe` on the `patients` table.

# %%
patients.describe()
# Out:
#        patient_id      zip_code      weight      height         bmi
# count  503.000000    491.000000  503.000000  503.000000  503.000000
# mean   252.000000  49084.118126  173.434990   66.634195   27.483897
# std    145.347859  30265.807442   33.916741    4.411297    5.276438
# min      1.000000   1002.000000   48.800000   27.000000   17.100000
# 25%    126.500000  21920.500000  149.300000   63.000000   23.300000
# 50%    252.000000  48057.000000  175.300000   67.000000   27.200000
# 75%    377.500000  75679.000000  199.500000   70.000000   31.750000
# max    503.000000  99701.000000  255.900000   79.000000   37.700000

# %% [markdown]
# Try `.value_counts` on the *adverse_reaction* column of the `adverse_reactions` table.

# %%
adverse_reactions["adverse_reaction"].value_counts()
# Out:
# hypoglycemia                 19
# injection site discomfort     6
# headache                      3
# cough                         2
# nausea                        2
# throat irritation             2
# Name: adverse_reaction, dtype: int64

# %% [markdown]
# Try selecting the records in the `patients` table for patients that are from the *city* New York.

# %%
patients.query(" city=='{}' | city=='{}' | city=='{}' ".format("New York","York","NY")).T
# Out:
#                                            2    \
# patient_id                                   3
# assigned_sex                              male
# given_name                                 Jae
# surname                                 Debord
# address                  1493 Poling Farm Road
# city                                      York
# state                                 Nebraska
# zip_code                                 68467
# country                          United States
# contact       402-363-6804JaeMDebord@gustr.com
# birthdate                            2/19/1980
# weight                                   177.8
# height                                      71
# bmi                                       24.8
#
#                                                         9    \
# patient_id                                               10
# assigned_sex                                         female
# given_name                                           Sophie
# surname                                             Cabrera
# address                                   3303 Anmoore Road
# city                                               New York
# state                                              New York
# zip_code                                              10011
# country                                       United States
# contact       SophieCabreraIbarra@teleworm.us1 718 795 9124
# birthdate                                         12/3/1930
# weight                                                194.7
# height                                                   64
# bmi                                                    33.4
#
#                                                 35   \
# patient_id                                       36
# assigned_sex                                 female
# given_name                                   Kamila
# surname                                    Pecinová
# address                        3558 Longview Avenue
# city                                       New York
# state                                      New York
# zip_code                                      10004
# country                               United States
# contact       718-501-0503KamilaPecinova@dayrep.com
# birthdate                                12/23/1985
# weight                                        198.9
# height                                           62
# bmi                                            36.4
#
#                                              84   \
# patient_id                                    85
# assigned_sex                              female
# given_name                                 Nương
# surname                                       Vũ
# address                      465 Southern Street
# city                                    New York
# state                                         NY
# zip_code                                   10001
# country                            United States
# contact       VuCamNuong@fleckens.hu516-720-5094
# birthdate                               2/1/1981
# weight                                     138.2
# height                                        63
# bmi                                         24.5
#
#                                                   129  \
# patient_id                                        130
# assigned_sex                                   female
# given_name                                    Rebecca
# surname                                      Jephcott
# address                              989 Wayback Lane
# city                                         New York
# state                                              NY
# zip_code                                        10004
# country                                 United States
# contact       631-370-7406RebeccaJephcott@armyspy.com
# birthdate                                    8/1/1966
# weight                                          203.3
# height                                             65
# bmi                                              33.8
#
#                                                 142  \
# patient_id                                      143
# assigned_sex                                   male
# given_name                                   Finley
# surname                                    Chandler
# address                        2754 Westwood Avenue
# city                                       New York
# state                                      New York
# zip_code                                      10001
# country                               United States
# contact       516-740-5280FinleyChandler@dayrep.com
# birthdate                                10/25/1936
# weight                                        150.9
# height                                           70
# bmi                                            21.6
#
#                                                             152  \
# patient_id                                                  153
# assigned_sex                                               male
# given_name                                          Christopher
# surname                                                Woodward
# address                                    3450 Southern Street
# city                                                   New York
# state                                                        NY
# zip_code                                                  10004
# country                                           United States
# contact       ChristopherWoodward@jourrapide.com+1 (516) 630...
# birthdate                                              9/4/1984
# weight                                                    212.2
# height                                                       66
# bmi                                                        34.2
#
#                                                   188  \
# patient_id                                        189
# assigned_sex                                     male
# given_name                                      Søren
# surname                                      Sørensen
# address                              2397 Bell Street
# city                                         New York
# state                                              NY
# zip_code                                        10011
# country                                 United States
# contact       SrenSrensen@superrito.com1 212 201 3108
# birthdate                                  12/31/1942
# weight                                          157.1
# height                                             67
# bmi                                              24.6
#
#                                                      213  \
# patient_id                                           214
# assigned_sex                                      female
# given_name                                    Onyemaechi
# surname                                        Onwughara
# address                                685 Duncan Avenue
# city                                            New York
# state                                                 NY
# zip_code                                           10013
# country                                    United States
# contact       917-622-9142OnyemaechiOnwughara@einrot.com
# birthdate                                       3/8/1989
# weight                                             131.1
# height                                                69
# bmi                                                 19.4
#
#                                       215                          229  \
# patient_id                            216                          230
# assigned_sex                         male                         male
# given_name                           John                         John
# surname                               Doe                          Doe
# address                   123 Main Street              123 Main Street
# city                             New York                     New York
# state                                  NY                           NY
# zip_code                            12345                        12345
# country                     United States                United States
# contact       johndoe@email.com1234567890  johndoe@email.com1234567890
# birthdate                        1/1/1975                     1/1/1975
# weight                                180                          180
# height                                 72                           72
# bmi                                  24.4                         24.4
#
#                                       237                          244  \
# patient_id                            238                          245
# assigned_sex                         male                         male
# given_name                           John                         John
# surname                               Doe                          Doe
# address                   123 Main Street              123 Main Street
# city                             New York                     New York
# state                                  NY                           NY
# zip_code                            12345                        12345
# country                     United States                United States
# contact       johndoe@email.com1234567890  johndoe@email.com1234567890
# birthdate                        1/1/1975                     1/1/1975
# weight                                180                          180
# height                                 72                           72
# bmi                                  24.4                         24.4
#
#                                                    247  \
# patient_id                                         248
# assigned_sex                                      male
# given_name                                      Tuukka
# surname                                     Leppäluoto
# address                             1886 Bicetown Road
# city                                          New York
# state                                               NY
# zip_code                                         10011
# country                                  United States
# contact       917-408-8855TuukkaLeppaluoto@teleworm.us
# birthdate                                     3/7/1978
# weight                                             211
# height                                              73
# bmi                                               27.8
#
#                                       251  \
# patient_id                            252
# assigned_sex                         male
# given_name                           John
# surname                               Doe
# address                   123 Main Street
# city                             New York
# state                                  NY
# zip_code                            12345
# country                     United States
# contact       johndoe@email.com1234567890
# birthdate                        1/1/1975
# weight                                180
# height                                 72
# bmi                                  24.4
#
#                                                             263  \
# patient_id                                                  264
# assigned_sex                                             female
# given_name                                                Julia
# surname                                                Carvalho
# address                                       3662 Shinn Street
# city                                                   New York
# state                                                        NY
# zip_code                                                  10036
# country                                           United States
# contact       JuliaAzevedoCarvalho@superrito.com+1 (212) 782...
# birthdate                                             4/11/1931
# weight                                                    171.8
# height                                                       61
# bmi                                                        32.5
#
#                                       277  \
# patient_id                            278
# assigned_sex                         male
# given_name                           John
# surname                               Doe
# address                   123 Main Street
# city                             New York
# state                                  NY
# zip_code                            12345
# country                     United States
# contact       johndoe@email.com1234567890
# birthdate                        1/1/1975
# weight                                180
# height                                 72
# bmi                                  24.4
#
#                                                      301  \
# patient_id                                           302
# assigned_sex                                      female
# given_name                                  Onyekachukwu
# surname                                           Obinna
# address                               2970 Forest Avenue
# city                                            New York
# state                                                 NY
# zip_code                                           10004
# country                                    United States
# contact       OnyekachukwuObinna@teleworm.us646-982-6609
# birthdate                                      1/24/1997
# weight                                             154.7
# height                                                65
# bmi                                                 25.7
#
#                                                          461
# patient_id                                               462
# assigned_sex                                            male
# given_name                                            Cannan
# surname                                              Cabrera
# address                                  2102 Geraldine Lane
# city                                                New York
# state                                                     NY
# zip_code                                               10014
# country                                        United States
# contact       646-289-4177CannanCabreraOrdonez@superrito.com
# birthdate                                         10/12/1980
# weight                                                 209.7
# height                                                    71
# bmi                                                     29.2
