# %% [markdown]
# ## Gather

# %%
import pandas as pd

# %%
patients = pd.read_csv('patients.csv')
treatments = pd.read_csv('treatments.csv')
adverse_reactions = pd.read_csv('adverse_reactions.csv')

# %% [markdown]
# ## Assess

# %%
patients.T
# Out:
#                                                0    \
# patient_id                                       1
# assigned_sex                                female
# given_name                                     Zoe
# surname                                    Wellish
# address                       576 Brown Bear Drive
# city                             Rancho California
# state                                   California
# zip_code                                     92390
# country                              United States
# contact       951-719-9170ZoeWellish@superrito.com
# birthdate                                7/10/1976
# weight                                       121.7
# height                                          66
# bmi                                           19.6
#
#                                                 1    \
# patient_id                                        2
# assigned_sex                                 female
# given_name                                   Pamela
# surname                                        Hill
# address                   2370 University Hill Road
# city                                      Armstrong
# state                                      Illinois
# zip_code                                      61812
# country                               United States
# contact       PamelaSHill@cuvox.de+1 (217) 569-3204
# birthdate                                  4/3/1967
# weight                                        118.8
# height                                           66
# bmi                                            19.2
#
#                                            2    \
# patient_id                                   3
# assigned_sex                              male
# given_name                                 Jae
# surname                                 Debord
# address                  1493 Poling Farm Road
# city                                      York
# state                                 Nebraska
# zip_code                                 68467
# country                          United States
# contact       402-363-6804JaeMDebord@gustr.com
# birthdate                            2/19/1980
# weight                                   177.8
# height                                      71
# bmi                                       24.8
#
#                                                      3    \
# patient_id                                             4
# assigned_sex                                        male
# given_name                                          Liêm
# surname                                             Phan
# address                              2335 Webster Street
# city                                          Woodbridge
# state                                                 NJ
# zip_code                                            7095
# country                                    United States
# contact       PhanBaLiem@jourrapide.com+1 (732) 636-8246
# birthdate                                      7/26/1951
# weight                                             220.9
# height                                                70
# bmi                                                 31.7
#
#                                           4    \
# patient_id                                  5
# assigned_sex                             male
# given_name                                Tim
# surname                               Neudorf
# address                  1428 Turkey Pen Lane
# city                                   Dothan
# state                                      AL
# zip_code                                36303
# country                         United States
# contact       334-515-7487TimNeudorf@cuvox.de
# birthdate                           2/18/1928
# weight                                  192.3
# height                                     27
# bmi                                      26.1
#
#                                                    5    \
# patient_id                                           6
# assigned_sex                                      male
# given_name                                      Rafael
# surname                                          Costa
# address                             1140 Willis Avenue
# city                                     Daytona Beach
# state                                          Florida
# zip_code                                         32114
# country                                  United States
# contact       386-334-5237RafaelCardosoCosta@gustr.com
# birthdate                                    8/31/1931
# weight                                           183.9
# height                                              70
# bmi                                               26.4
#
#                                             6    \
# patient_id                                    7
# assigned_sex                             female
# given_name                                 Mary
# surname                                   Adams
# address                        3145 Sheila Lane
# city                                    Burbank
# state                                        NV
# zip_code                                  84728
# country                           United States
# contact       775-533-5933MaryBAdams@einrot.com
# birthdate                            11/19/1969
# weight                                    146.3
# height                                       65
# bmi                                        24.3
#
#                                                7    \
# patient_id                                       8
# assigned_sex                                female
# given_name                                  Xiuxiu
# surname                                      Chang
# address                 2687 Black Oak Hollow Road
# city                                   Morgan Hill
# state                                           CA
# zip_code                                     95037
# country                              United States
# contact       XiuxiuChang@einrot.com1 408 778 3236
# birthdate                                8/13/1958
# weight                                         158
# height                                          60
# bmi                                           30.9
#
#                                                   8    \
# patient_id                                          9
# assigned_sex                                     male
# given_name                                      Dsvid
# surname                                    Gustafsson
# address                            1790 Nutter Street
# city                                      Kansas City
# state                                              MO
# zip_code                                        64105
# country                                 United States
# contact       816-265-9578DavidGustafsson@armyspy.com
# birthdate                                    3/6/1937
# weight                                          163.9
# height                                             66
# bmi                                              26.5
#
#                                                         9    \
# patient_id                                               10
# assigned_sex                                         female
# given_name                                           Sophie
# surname                                             Cabrera
# address                                   3303 Anmoore Road
# city                                               New York
# state                                              New York
# zip_code                                              10011
# country                                       United States
# contact       SophieCabreraIbarra@teleworm.us1 718 795 9124
# birthdate                                         12/3/1930
# weight                                                194.7
# height                                                   64
# bmi                                                    33.4
#
#                               ...                   \
# patient_id                    ...
# assigned_sex                  ...
# given_name                    ...
# surname                       ...
# address                       ...
# city                          ...
# state                         ...
# zip_code                      ...
# country                       ...
# contact                       ...
# birthdate                     ...
# weight                        ...
# height                        ...
# bmi                           ...
#
#                                              493  \
# patient_id                                   494
# assigned_sex                              female
# given_name                                   Fen
# surname                                     Chin
# address                   1826 Poplar Chase Lane
# city                                       Boise
# state                                         ID
# zip_code                                   83702
# country                            United States
# contact       FenChin@gustr.com+1 (208) 388-1065
# birthdate                              3/18/1997
# weight                                     195.1
# height                                        68
# bmi                                         29.7
#
#                                                        494  \
# patient_id                                             495
# assigned_sex                                        female
# given_name                                          Sirkka
# surname                                          Piirainen
# address                                 4102 Ritter Avenue
# city                                             Roseville
# state                                                   MI
# zip_code                                             48066
# country                                      United States
# contact       SirkkaPiirainen@teleworm.us+1 (586) 790-0975
# birthdate                                        1/16/1942
# weight                                               126.3
# height                                                  67
# bmi                                                   19.8
#
#                                                495  \
# patient_id                                     496
# assigned_sex                                  male
# given_name                                  Hajime
# surname                                    Tsukada
# address                          4111 Thunder Road
# city                                     San Mateo
# state                                           CA
# zip_code                                     94403
# country                              United States
# contact       650-570-4896HajimeTsukada@dayrep.com
# birthdate                                 9/5/1972
# weight                                       168.1
# height                                          66
# bmi                                           27.1
#
#                                                        496  \
# patient_id                                             497
# assigned_sex                                          male
# given_name                                       Alexander
# surname                                             Hueber
# address                                   3868 Freed Drive
# city                                              Stockton
# state                                           California
# zip_code                                             95204
# country                                      United States
# contact       AlexanderHueber@jourrapide.com1 209 762 2320
# birthdate                                        9/12/1942
# weight                                                 194
# height                                                  72
# bmi                                                   26.3
#
#                                                        497  \
# patient_id                                             498
# assigned_sex                                          male
# given_name                                        Masataka
# surname                                           Murakami
# address                                   1179 Patton Lane
# city                                                 Tulsa
# state                                                   OK
# zip_code                                             74116
# country                                      United States
# contact       MasatakaMurakami@einrot.com+1 (918) 984-9171
# birthdate                                        8/19/1937
# weight                                               155.1
# height                                                  72
# bmi                                                     21
#
#                                                       498  \
# patient_id                                            499
# assigned_sex                                         male
# given_name                                        Mustafa
# surname                                         Lindström
# address                               2530 Victoria Court
# city                                         Milton Mills
# state                                                  ME
# zip_code                                             3852
# country                                     United States
# contact       207-477-0579MustafaLindstrom@jourrapide.com
# birthdate                                       4/10/1959
# weight                                              181.1
# height                                                 72
# bmi                                                  24.6
#
#                                              499  \
# patient_id                                   500
# assigned_sex                                male
# given_name                                 Ruman
# surname                                  Bisliev
# address                 494 Clarksburg Park Road
# city                                      Sedona
# state                                         AZ
# zip_code                                   86341
# country                            United States
# contact       928-284-4492RumanBisliev@gustr.com
# birthdate                              3/26/1948
# weight                                     239.6
# height                                        70
# bmi                                         34.4
#
#                                                 500  \
# patient_id                                      501
# assigned_sex                                 female
# given_name                                    Jinke
# surname                                   de Keizer
# address                           649 Nutter Street
# city                                  Overland Park
# state                                            MO
# zip_code                                      64110
# country                               United States
# contact       816-223-6007JinkedeKeizer@teleworm.us
# birthdate                                 1/13/1971
# weight                                        171.2
# height                                           67
# bmi                                            26.8
#
#                                                           501  \
# patient_id                                                502
# assigned_sex                                           female
# given_name                                            Chidalu
# surname                                           Onyekaozulu
# address                              3652 Boone Crockett Lane
# city                                                  Seattle
# state                                                      WA
# zip_code                                                98109
# country                                         United States
# contact       ChidaluOnyekaozulu@jourrapide.com1 360 443 2060
# birthdate                                           2/13/1952
# weight                                                  176.9
# height                                                     67
# bmi                                                      27.7
#
#                                                502
# patient_id                                     503
# assigned_sex                                  male
# given_name                                     Pat
# surname                                    Gersten
# address                          2778 North Avenue
# city                                          Burr
# state                                     Nebraska
# zip_code                                     68324
# country                              United States
# contact       PatrickGersten@rhyta.com402-848-4923
# birthdate                                 5/3/1954
# weight                                       138.2
# height                                          71
# bmi                                           19.3
#
# [14 rows x 503 columns]

# %%
treatments
# Out:
#       given_name       surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0       veronika      jindrová  41u - 48u          -         7.63       7.20
# 1         elliot    richardson          -  40u - 45u         7.56       7.09
# 2       yukitaka      takenaka          -  39u - 36u         7.68       7.25
# 3           skye    gormanston  33u - 36u          -         7.97       7.62
# 4         alissa        montez          -  33u - 29u         7.78       7.46
# 5        jasmine         sykes          -  42u - 44u         7.56       7.18
# 6         sophia        haugen  37u - 42u          -         7.65       7.27
# 7          eddie        archer  31u - 38u          -         7.89       7.55
# 8          saber        ménard          -  54u - 54u         8.08       7.70
# 9           asia       woźniak  30u - 36u          -         7.76       7.37
# 10        joseph           day  29u - 36u          -         7.70       7.19
# 11     kristiina        hyypiä          -  36u - 38u         7.87       7.49
# 12       roxanne     andreyeva  29u - 38u          -         9.54       9.14
# 13        gregor          bole          -  47u - 45u         7.61       7.16
# 14        simone  baumgaertner  27u - 37u          -         7.74       7.30
# 15          enco        žibrik  55u - 68u          -         7.78       7.34
# 16       camilla      zaitseva  28u - 37u          -         7.53       7.13
# 17          gina          cain          -  36u - 36u         7.88       7.40
# 18    addolorata      lombardi          -  49u - 46u         7.75       7.33
# 19        khalid      johnsrud          -  54u - 54u         8.35       7.94
# 20          mile        stanić          -  47u - 48u         7.66       7.24
# 21         tekla       walczak  29u - 39u          -         7.61       7.29
# 22   brancaleone         russo  53u - 60u          -         8.61       8.18
# 23      chiemela     tobeolisa          -  43u - 47u         7.59       7.17
# 24          isac          berg  31u - 41u          -         9.68       9.29
# 25        benoît        bonami          -  44u - 43u         9.82       9.40
# 26        suhaim         rahal          -  49u - 47u         7.94       7.50
# 27        mizuki         iwata          -  45u - 46u         7.70       7.23
# 28       clinton        miller  42u - 51u          -         7.79       7.40
# 29        eugene       mironov  42u - 49u          -         7.81       7.48
# ..           ...           ...        ...        ...          ...        ...
# 250         chen           yao          -  56u - 57u         7.90       7.51
# 251        aksel   vestergaard          -  42u - 38u         9.62       9.29
# 252        ellen         luman          -  40u - 39u         9.27       8.77
# 253       albino     schiavone  35u - 43u          -         7.56       7.15
# 254         jose         combs          -  39u - 36u         7.89       7.42
# 255       jia li          teng  48u - 54u          -         7.66       7.32
# 256        ilija        horvat  42u - 50u          -         7.77       7.38
# 257     mathilde      nørgaard          -  27u - 28u         8.50       8.10
# 258       csilla      herczegh          -  43u - 46u         7.71       7.27
# 259      aaliyah          rice          -  31u - 31u         7.64       7.33
# 260        david      beauvais          -  26u - 23u         7.87       7.47
# 261     caroline        shuler          -  50u - 54u         7.63       7.27
# 262         alex      crawford  51u - 62u          -         7.69       7.30
# 263      rebecca      jephcott  53u - 63u          -         7.96       7.57
# 264   chukwumoge     ogochukwu          -  41u - 39u         7.95       7.56
# 265       fearne      mcgregor          -  27u - 29u         7.83       7.48
# 266       ursula         freud  42u - 54u          -         7.75       7.46
# 267         leon        scholz          -  38u - 32u         7.72       7.29
# 268       yasmin        araujo          -  51u - 54u         7.82       7.36
# 269       hiromu      horikawa          -  47u - 46u         7.77       7.28
# 270         mika    martinsson  34u - 43u          -         7.50       7.17
# 271          leo        vieira          -  30u - 33u         7.74       7.36
# 272       steven           roy          -  41u - 43u         7.87       7.43
# 273         kate     wilkinson  36u - 39u          -         7.72       7.20
# 274         naja       enoksen  43u - 50u          -         7.98       7.59
# 275       albina      zetticci  45u - 51u          -         7.93       7.73
# 276         john   teichelmann          -  49u - 49u         7.90       7.58
# 277       mathea       lillebø  23u - 36u          -         9.04       8.67
# 278       vallie        prince  31u - 38u          -         7.64       7.28
# 279       samúel  guðbrandsson  53u - 56u          -         8.00       7.64
#
#      hba1c_change
# 0             NaN
# 1            0.97
# 2             NaN
# 3            0.35
# 4            0.32
# 5            0.38
# 6            0.38
# 7            0.34
# 8             NaN
# 9             NaN
# 10            NaN
# 11           0.38
# 12            NaN
# 13           0.95
# 14            NaN
# 15            NaN
# 16            NaN
# 17           0.98
# 18            NaN
# 19            NaN
# 20           0.92
# 21           0.32
# 22            NaN
# 23            NaN
# 24           0.39
# 25           0.92
# 26           0.94
# 27           0.97
# 28           0.39
# 29           0.33
# ..            ...
# 250          0.39
# 251           NaN
# 252          0.50
# 253           NaN
# 254           NaN
# 255          0.34
# 256          0.39
# 257          0.90
# 258           NaN
# 259          0.31
# 260           NaN
# 261           NaN
# 262          0.39
# 263          0.39
# 264          0.39
# 265          0.35
# 266          0.29
# 267          0.93
# 268          0.96
# 269           NaN
# 270          0.33
# 271           NaN
# 272          0.94
# 273           NaN
# 274           NaN
# 275          0.20
# 276           NaN
# 277          0.37
# 278          0.36
# 279          0.36
#
# [280 rows x 7 columns]

# %%
adverse_reactions
# Out:
#      given_name     surname           adverse_reaction
# 0         berta  napolitani  injection site discomfort
# 1          lena        baer               hypoglycemia
# 2        joseph         day               hypoglycemia
# 3        flavia  fiorentino                      cough
# 4       manouck     wubbels          throat irritation
# 5       jasmine       sykes               hypoglycemia
# 6        louise     johnson               hypoglycemia
# 7       albinca     komavec               hypoglycemia
# 8           noe      aranda               hypoglycemia
# 9         sofia   hermansen  injection site discomfort
# 10        tegan     johnson                   headache
# 11         abel     yonatan                      cough
# 12    abdul-nur         isa               hypoglycemia
# 13         leon      scholz  injection site discomfort
# 14     gabriele     saenger               hypoglycemia
# 15       jia li        teng                     nausea
# 16        jakob    jakobsen               hypoglycemia
# 17  christopher    woodward                     nausea
# 18          ole    petersen               hypoglycemia
# 19       finley    chandler                   headache
# 20     anenechi       chidi               hypoglycemia
# 21     miłosław  wiśniewski  injection site discomfort
# 22        lixue       hsueh  injection site discomfort
# 23        merci      leroux               hypoglycemia
# 24         kang         mai  injection site discomfort
# 25       elliot  richardson               hypoglycemia
# 26      clinton      miller          throat irritation
# 27       idalia       moore               hypoglycemia
# 28       xiuxiu       chang               hypoglycemia
# 29         alex    crawford               hypoglycemia
# 30       monika      lončar               hypoglycemia
# 31       steven         roy                   headache
# 32      cecilie      nilsen               hypoglycemia
# 33    krisztina      magyar               hypoglycemia

# %%
patients.surname.value_counts()
# Out:
# Doe              6
# Taylor           3
# Jakobsen         3
# Bùi              2
# Berg             2
# Silva            2
# Johnson          2
# Nilsen           2
# Cindrić          2
# Souza            2
# Liễu             2
# Kowalczyk        2
# Lund             2
# Correia          2
# Aranda           2
# Tạ               2
# Grímsdóttir      2
# Lâm              2
# Schiavone        2
# Gersten          2
# Tucker           2
# Parker           2
# Cabrera          2
# Collins          2
# Ogochukwu        2
# Hueber           2
# Lương            2
# Dratchev         2
# Kadyrov          2
# Woźniak          2
#                 ..
# Hrafnsdóttir     1
# Archer           1
# Arsanukayev      1
# Lê               1
# Tryggvadóttir    1
# Su               1
# Martinsson       1
# Terrazas         1
# Villadsen        1
# Allan            1
# Ouwendijk        1
# Montez           1
# Clapp            1
# Abdulov          1
# Macleod          1
# Tikhonov         1
# Ghanem           1
# Michalčíková     1
# Vukelić          1
# Hsu              1
# Frederiksen      1
# Bidwill          1
# Bowden           1
# Amanuel          1
# Fiorentino       1
# Richardson       1
# Nucci            1
# Bois             1
# Werner           1
# Andreyeva        1
# Name: surname, Length: 466, dtype: int64

# %%
patients.address.value_counts()
# Out:
# 123 Main Street               6
# 2778 North Avenue             2
# 648 Old Dear Lane             2
# 2476 Fulton Street            2
# 1333 Comfort Court            1
# 1343 Clair Street             1
# 1346 Nicholas Street          1
# 3542 Robinson Court           1
# 4223 Chestnut Street          1
# 2246 Pheasant Ridge Road      1
# 4278 Hart Country Lane        1
# 2641 Michael Street           1
# 2146 Willow Greene Drive      1
# 4556 Oakdale Avenue           1
# 4789 Devils Hill Road         1
# 3781 Hamill Avenue            1
# 1840 Millbrook Road           1
# 2957 Feathers Hooves Drive    1
# 1510 Allison Avenue           1
# 383 Marion Street             1
# 3072 Braxton Street           1
# 3165 Upton Avenue             1
# 3423 Burning Memory Lane      1
# 1965 Crestview Manor          1
# 4795 Better Street            1
# 3731 Swick Hill Street        1
# 4213 Isaacs Creek Road        1
# 3417 Bassel Street            1
# 430 Canis Heights Drive       1
# 649 Nutter Street             1
#                              ..
# 350 Ross Street               1
# 4870 Corbin Branch Road       1
# 3113 Timber Ridge Road        1
# 1330 Lincoln Street           1
# 541 Green Hill Road           1
# 3539 Bottom Lane              1
# 4243 Hidden Meadow Drive      1
# 1790 Nutter Street            1
# 826 Broad Street              1
# 4912 Hart Country Lane        1
# 2945 Ferguson Street          1
# 4155 Raccoon Run              1
# 3343 Jefferson Street         1
# 3958 Liberty Avenue           1
# 3893 Eva Pearl Street         1
# 4093 Smith Street             1
# 2544 Worley Avenue            1
# 3499 Baker Avenue             1
# 2607 Water Street             1
# 77 Juniper Drive              1
# 2661 Russell Street           1
# 2636 Benson Park Drive        1
# 1808 Stuart Street            1
# 550 Cliffside Drive           1
# 272 Boone Crockett Lane       1
# 632 Peaceful Lane             1
# 4334 Black Oak Hollow Road    1
# 2011 Eastland Avenue          1
# 4894 Chandler Hollow Road     1
# 153 Fieldcrest Road           1
# Name: address, Length: 483, dtype: int64

# %%
patients[patients.address.duplicated()].T
# Out:
#                                                      29        219  \
# patient_id                                            30       220
# assigned_sex                                        male      male
# given_name                                          Jake        Mỹ
# surname                                         Jakobsen     Quynh
# address                                648 Old Dear Lane       NaN
# city                                         Port Jervis       NaN
# state                                           New York       NaN
# zip_code                                           12771       NaN
# country                                    United States       NaN
# contact       JakobCJakobsen@einrot.com+1 (845) 858-7707       NaN
# birthdate                                       8/1/1985  4/9/1978
# weight                                             155.8     237.8
# height                                                67        69
# bmi                                                 24.4      35.1
#
#                                       229        230        234  \
# patient_id                            230        231        235
# assigned_sex                         male     female     female
# given_name                           John  Elisabeth    Martina
# surname                               Doe    Knudsen  Tománková
# address                   123 Main Street        NaN        NaN
# city                             New York        NaN        NaN
# state                                  NY        NaN        NaN
# zip_code                            12345        NaN        NaN
# country                     United States        NaN        NaN
# contact       johndoe@email.com1234567890        NaN        NaN
# birthdate                        1/1/1975  9/23/1976   4/7/1936
# weight                                180      165.9      199.5
# height                                 72         63         65
# bmi                                  24.4       29.4       33.2
#
#                                       237        242  \
# patient_id                            238        243
# assigned_sex                         male       male
# given_name                           John       John
# surname                               Doe    O'Brian
# address                   123 Main Street        NaN
# city                             New York        NaN
# state                                  NY        NaN
# zip_code                            12345        NaN
# country                     United States        NaN
# contact       johndoe@email.com1234567890        NaN
# birthdate                        1/1/1975  2/25/1957
# weight                                180      205.3
# height                                 72         74
# bmi                                  24.4       26.4
#
#                                       244         249  \
# patient_id                            245         250
# assigned_sex                         male        male
# given_name                           John    Benjamin
# surname                               Doe      Mehler
# address                   123 Main Street         NaN
# city                             New York         NaN
# state                                  NY         NaN
# zip_code                            12345         NaN
# country                     United States         NaN
# contact       johndoe@email.com1234567890         NaN
# birthdate                        1/1/1975  10/30/1951
# weight                                180       146.5
# height                                 72          69
# bmi                                  24.4        21.6
#
#                                       251        257        264         269  \
# patient_id                            252        258        265         270
# assigned_sex                         male       male     female      female
# given_name                           John        Jin   Wafiyyah      Flavia
# surname                               Doe       Kung     Asfour  Fiorentino
# address                   123 Main Street        NaN        NaN         NaN
# city                             New York        NaN        NaN         NaN
# state                                  NY        NaN        NaN         NaN
# zip_code                            12345        NaN        NaN         NaN
# country                     United States        NaN        NaN         NaN
# contact       johndoe@email.com1234567890        NaN        NaN         NaN
# birthdate                        1/1/1975  5/17/1995  11/3/1989   10/9/1937
# weight                                180      231.7      158.6       175.2
# height                                 72         69         63          61
# bmi                                  24.4       34.2       28.1        33.1
#
#                                       277         278  \
# patient_id                            278         279
# assigned_sex                         male      female
# given_name                           John    Generosa
# surname                               Doe       Cabán
# address                   123 Main Street         NaN
# city                             New York         NaN
# state                                  NY         NaN
# zip_code                            12345         NaN
# country                     United States         NaN
# contact       johndoe@email.com1234567890         NaN
# birthdate                        1/1/1975  12/16/1962
# weight                                180       124.3
# height                                 72          69
# bmi                                  24.4        18.4
#
#                                                282       286        296  \
# patient_id                                     283       287        297
# assigned_sex                                female      male     female
# given_name                                   Sandy     Lewis        Chỉ
# surname                                     Taylor      Webb        Lâm
# address                         2476 Fulton Street       NaN        NaN
# city                                      Rainelle       NaN        NaN
# state                                           WV       NaN        NaN
# zip_code                                     25962       NaN        NaN
# country                              United States       NaN        NaN
# contact       304-438-2648SandraCTaylor@dayrep.com       NaN        NaN
# birthdate                               10/23/1960  4/1/1979  5/14/1990
# weight                                       206.1     155.3      181.1
# height                                          64        68         63
# bmi                                           35.4      23.6       32.1
#
#                                                502
# patient_id                                     503
# assigned_sex                                  male
# given_name                                     Pat
# surname                                    Gersten
# address                          2778 North Avenue
# city                                          Burr
# state                                     Nebraska
# zip_code                                     68324
# country                              United States
# contact       PatrickGersten@rhyta.com402-848-4923
# birthdate                                 5/3/1954
# weight                                       138.2
# height                                          71
# bmi                                           19.3

# %%
patients.weight.sort_values()
# Out:
# 210     48.8
# 459    102.1
# 335    102.7
# 74     103.2
# 317    106.0
# 171    106.5
# 51     107.1
# 270    108.1
# 198    108.5
# 48     109.1
# 478    109.6
# 141    110.2
# 38     111.8
# 438    112.0
# 14     112.0
# 235    112.2
# 307    112.4
# 191    112.6
# 408    113.1
# 49     113.3
# 326    114.0
# 338    114.1
# 253    117.0
# 321    118.4
# 168    118.8
# 1      118.8
# 350    119.0
# 207    119.2
# 265    120.0
# 341    120.3
#        ...
# 332    224.0
# 252    224.2
# 12     224.2
# 222    224.8
# 166    225.3
# 111    225.9
# 101    226.2
# 150    226.6
# 352    227.7
# 428    227.7
# 88     227.7
# 13     228.4
# 339    229.0
# 182    230.3
# 121    230.8
# 257    231.7
# 395    231.9
# 246    232.1
# 219    237.8
# 11     238.7
# 50     238.9
# 441    239.1
# 499    239.6
# 439    242.0
# 487    242.4
# 144    244.9
# 61     244.9
# 283    245.5
# 118    254.5
# 485    255.9
# Name: weight, Length: 503, dtype: float64

# %%
sum(treatments.auralin.isnull())
# Out:
# 0

# %%
sum(treatments.novodra.isnull())
# Out:
# 0
